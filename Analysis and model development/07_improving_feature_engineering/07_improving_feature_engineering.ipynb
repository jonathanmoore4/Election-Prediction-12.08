# %% [markdown]
# # Improving feature engineering
#
# Read the training dataset from `TEST_TRAIN/train.csv` and list its columns.

# %%
from pathlib import Path
import pandas as pd

# Locate the repository whether running from its root or this notebook's folder.
ROOT = next(
    (path for path in [Path.cwd(), *Path.cwd().parents]
     if (path / "TEST_TRAIN" / "train.csv").is_file()),
    None,
)
if ROOT is None:
    raise FileNotFoundError("Run this notebook from inside the repository.")

train = pd.read_csv(ROOT / "TEST_TRAIN" / "train.csv")

# %%
for column in train.columns:
    print(column)
# Out:
# constituency_name
# country/region
# election
# winning_party_vote_share
# winner
# constituency_id
# boundary_set
# election_type
# con_share
# lib_share
# lab_share
# natSW_share
# previous_election
# previous_winning_party_last_election_vote_share
# previous_winner
# previous_con_share
# previous_lib_share
# previous_lab_share
# previous_natSW_share
# con_polling
# lab_polling
# lib_polling
# incumbent
# supported_incumbent
# incumbent_polling
# opposition_polling
# previous_nat_con_share
# previous_nat_lib_share
# previous_nat_lab_share
# previous_nat_natSW_share
# projected_con_share
# projected_lib_share
# projected_lab_share
